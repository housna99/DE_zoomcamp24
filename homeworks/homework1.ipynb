# %%
import pandas as pd

# %%
data_zone=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv')
data_zone.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df=pd.read_csv('green_tripdata_2019-09.csv')
df.head()
# Out:
# C:\Users\houss\AppData\Local\Temp\ipykernel_36684\290052370.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('green_tripdata_2019-09.csv')
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# ...

# %%
df.describe()
# Out:
#             VendorID     RatecodeID   PULocationID   DOLocationID  \
# count  389920.000000  389920.000000  449063.000000  449063.000000
# mean        1.837777       1.106971     108.139203     130.154678
# std         0.368656       0.723302      71.025032      76.577260
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       1.000000      56.000000      65.000000
# 50%         2.000000       1.000000      82.000000     129.000000
# 75%         2.000000       1.000000     166.000000     195.000000
# max         2.000000      99.000000     265.000000     265.000000
#
#        passenger_count  trip_distance    fare_amount          extra  \
# count    389920.000000  449063.000000  449063.000000  449063.000000
# mean          1.311900       3.519991      15.491455       0.697539
# std           0.969761       4.083097      13.561680       1.022319
# min           0.000000       0.000000    -200.000000      -4.500000
# ...

# %%
df.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
print(pd.io.sql.get_schema(df, name="taxi_data"))
# Out:
# CREATE TABLE "taxi_data" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL
# )

# %% [markdown]
# # Convert from TEXT to datetime

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %% [markdown]
# # Convert from datetime to only date

# %%
print(df.lpep_pickup_datetime.dt.date)
# Out:
# 0         2019-09-01
# 1         2019-09-01
# 2         2019-09-01
# 3         2019-09-01
# 4         2019-09-01
#              ...
# 449058    2019-09-30
# 449059    2019-09-30
# 449060    2019-09-30
# 449061    2019-09-30
# 449062    2019-09-30
# Name: lpep_pickup_datetime, Length: 449063, dtype: object

# %%
df.lpep_pickup_datetime=df.lpep_pickup_datetime.dt.date

# %%
df.lpep_dropoff_datetime=df.lpep_dropoff_datetime.dt.date

# %%
print(pd.io.sql.get_schema(df, name="taxi_data"))
# Out:
# CREATE TABLE "taxi_data" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TIMESTAMP,
#   "lpep_dropoff_datetime" TIMESTAMP,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL
# )

# %%
#How many taxi trips were totally made on September 18th 2019?

#Tip: started and finished on 2019-09-18.

# %%
df['lpep_pickup_datetime']
# Out:
# 0        2019-09-01 00:10:53
# 1        2019-09-01 00:31:22
# 2        2019-09-01 00:50:24
# 3        2019-09-01 00:27:06
# 4        2019-09-01 00:43:23
#                  ...
# 449058   2019-09-30 23:13:00
# 449059   2019-09-30 23:26:00
# 449060   2019-09-30 23:15:00
# 449061   2019-09-30 23:19:00
# 449062   2019-09-30 23:35:00
# Name: lpep_pickup_datetime, Length: 449063, dtype: datetime64[ns]

# %%
print(pd.to_datetime('2019-09-01'))
# Out:
# 2019-09-01 00:00:00

# %%
selected_records=df[(df['lpep_pickup_datetime'] >= '2019-09-18 00:00:00') & (df['lpep_dropoff_datetime'] < '2019-09-19 00:00:00')]

# %%
print(selected_records)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 217634       2.0  2019-09-18 09:12:39   2019-09-18 09:20:14
# 218133       2.0  2019-09-18 10:05:23   2019-09-18 10:12:42
# 218134       2.0  2019-09-18 10:53:43   2019-09-18 11:00:01
# 218254       2.0  2019-09-18 00:02:54   2019-09-18 00:08:54
# 218281       2.0  2019-09-18 00:03:40   2019-09-18 00:23:29
# ...          ...                  ...                   ...
# 423824       NaN  2019-09-18 23:10:00   2019-09-18 23:28:00
# 423825       NaN  2019-09-18 23:18:00   2019-09-18 23:59:00
# 423828       NaN  2019-09-18 23:00:00   2019-09-18 23:15:00
# 423830       NaN  2019-09-18 23:19:00   2019-09-18 23:34:00
# 423831       NaN  2019-09-18 23:04:00   2019-09-18 23:14:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 217634                  N         1.0            95           134
# 218133                  N         1.0            95           196
# ...

# %%
total_records = len(selected_records)

# %%
print(total_records)
# Out:
# 15612

# %%
df[['trip_distance','lpep_pickup_datetime']].sort_values(by='trip_distance', ascending=False)
# Out:
#         trip_distance lpep_pickup_datetime
# 337292         341.64  2019-09-26 19:32:52
# 260941         135.53  2019-09-21 00:18:15
# 194647         114.30  2019-09-16 07:17:37
# 355914          89.64  2019-09-28 03:30:40
# 300408          82.12  2019-09-24 01:16:42
# ...               ...                  ...
# 236791           0.00  2019-09-19 13:50:01
# 352177           0.00  2019-09-27 21:19:05
# 109394           0.00  2019-09-09 14:54:41
# 197868           0.00  2019-09-16 11:28:05
# 132304           0.00  2019-09-11 15:15:55
#
# [449063 rows x 2 columns]

# %%
data_zone.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone
